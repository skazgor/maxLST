# %%
import heapq
import random
from collections import defaultdict
import math
import copy
import networkx as nx

class Graph:
    def __init__(self, num_vertices):
        self.num_vertices = num_vertices
        self.adj_matrix = [[0] * num_vertices for _ in range(num_vertices)]
        self.degrees = defaultdict(int)

    def add_edge(self, u, v):
        self.adj_matrix[u][v] = 1
        self.adj_matrix[v][u] = 1
        self.degrees[u] += 1
        self.degrees[v] += 1

    def degree(self, vertex):
        return sum(self.adj_matrix[vertex])
    
    def max_degree_vertex(self):
        return max(self.degrees, key=self.degrees.get)
    
    def copy(self):
        new_graph = Graph(self.num_vertices)
        new_graph.adj_matrix = copy.deepcopy(self.adj_matrix)
        new_graph.degrees = copy.deepcopy(self.degrees)
        return new_graph

    def to_networkx(self):
        G = nx.Graph()
        for i in range(self.num_vertices):
            for j in range(i + 1, self.num_vertices):
                if self.adj_matrix[i][j] == 1:
                    G.add_edge(i, j)
        return G

def priority_bfs(graph):
    start = graph.max_degree_vertex()
    T = Graph(graph.num_vertices)
    Q = []
    visited = set()  # Set to keep track of visited nodes
    heapq.heappush(Q, (-graph.degrees[start], start))
    visited.add(start)
    
    while Q:
        _, i = heapq.heappop(Q)
        for v in range(graph.num_vertices):  # Iterate over the adjacency matrix
            if graph.adj_matrix[i][v] == 1 and v not in visited:  # Check if there is an edge and the node is not visited
                priority = graph.degrees[v] - graph.degrees[i]
                heapq.heappush(Q, (-priority, v))
                T.add_edge(i, v)
                visited.add(v)  # Mark this node as visited

    return T


def random_neighbouring_tree(T,G):
    num_vertices = T.num_vertices
    # Step 1: Remove a random edge
    edges = []
    for i in range(num_vertices):
        for j in range(i+1, num_vertices):
            if T.adj_matrix[i][j] == 1:
                edges.append((i, j))
    random_edge = random.choice(edges)
    T.adj_matrix[random_edge[0]][random_edge[1]] = 0
    T.adj_matrix[random_edge[1]][random_edge[0]] = 0
    
    # Step 2: Find a random edge to reconnect the components
    disconnected_components = []
    visited = [False] * num_vertices
    for i in range(num_vertices):
        if not visited[i]:
            component = []
            stack = [i]
            while stack:
                v = stack.pop()
                component.append(v)
                visited[v] = True
                for j in range(num_vertices):
                    if T.adj_matrix[v][j] == 1 and not visited[j]:
                        stack.append(j)
            disconnected_components.append(component)
    
    # Pick two different components
    component_indices = list(range(len(disconnected_components)))
    i, j = random.sample(component_indices, 2)
    component1 = disconnected_components[i]
    component2 = disconnected_components[j]

    # find the edge to reconnect the components from the original graph
    edges = []
    for u in component1:
        for v in component2:
            if G.adj_matrix[u][v] == 1:
                edges.append((u, v))
    u, v = random.choice(edges)
    # Step 3: Add the random edge to reconnect the components
    T.adj_matrix[u][v] = 1
    T.adj_matrix[v][u] = 1

def fitness_function(T):
    num_leaves = 0
    total_weight = 0
    for i in range(T.num_vertices):
        degree = T.degree(i)
        if degree == 1:
            total_weight += 1
        elif degree == 2:
            total_weight += 0.5
        elif degree == 3:
            total_weight += 0.5
        elif degree > 3:
            total_weight += 0
        num_leaves += 1 if degree == 1 else 0
    return total_weight / T.num_vertices, num_leaves

def simulated_annealing(initial_tree, iterations, graph):
    current_tree = initial_tree
    current_fitness, _ = fitness_function(current_tree)
    temperature = 1.0
    cooling_rate = 0.995

    for _ in range(iterations):
        new_tree = current_tree.copy()
        random_neighbouring_tree(new_tree, graph)
        new_fitness, _ = fitness_function(new_tree)

        if new_fitness >= current_fitness or random.random() < math.exp((new_fitness - current_fitness - 1) / temperature):
            current_tree = new_tree
            current_fitness = new_fitness

        temperature *= cooling_rate

    return current_tree

def is_tree(graph):
    # A graph is a tree if it has n - 1 edges and is connected
    num_edges = sum(sum(row) for row in graph.adj_matrix) // 2
    num_nodes = graph.num_vertices
    return num_edges == num_nodes - 1 and is_connected(graph)

def is_connected(graph):
    # Use BFS to check if the graph is connected
    start = 0  # Start BFS from node 0
    visited = set()
    queue = [start]
    while queue:
        node = queue.pop(0)
        if node not in visited:
            visited.add(node)
            for i in range(graph.num_vertices):
                if graph.adj_matrix[node][i] == 1 and i not in visited:
                    queue.append(i)
    return len(visited) == graph.num_vertices

# Function to count leaf nodes in a graph
def count_leaf_nodes(graph):
    return sum(1 for i in range(graph.num_vertices) if graph.degree(i) == 1)


def read_graph_from_file(file_path):
    with open(file_path, 'r') as file:
        num_vertices , num_edges = map(int, file.readline().split())
        graph = Graph(num_vertices)
        graph.num_vertices = num_vertices
        for line in file:
            u, v = map(int, line.split())
            graph.add_edge(u, v)
    return graph

# %%
import time


print('algorithm,file_name,number_of_nodes,number_of_leaf_nodes,time_taken')
algorithm = 'Simulated_Annealing'


for file_prefix in ['complete_grid_graph_', 'incomplete_grid_graph_', 'random_d_regular_graph_', 'random_graph_', 'scale_free_graph_']:
    for i in range(1,11):
        file_path = f"{file_prefix}{i}.txt"
        graph = read_graph_from_file(file_path)

        start_time=time.time()

        initial_tree = priority_bfs(graph)
        assert is_tree(initial_tree) == True

        iterations = 1000
        result_tree = simulated_annealing(initial_tree, iterations, graph)

        assert is_tree(result_tree) == True

        end_time=time.time()

        resulting_graph = result_tree.to_networkx()

        print(f'{algorithm},{file_path},{resulting_graph.number_of_nodes()},{count_leaf_nodes(result_tree)},{end_time-start_time}')
# Out:
# algorithm,file_name,number_of_nodes,number_of_leaf_nodes,time_taken
# Simulated_Annealing,complete_grid_graph_1.txt,10,5,0.0982201099395752
# Simulated_Annealing,complete_grid_graph_2.txt,20,10,0.18739986419677734
# Simulated_Annealing,complete_grid_graph_3.txt,30,15,0.370314359664917
# Simulated_Annealing,complete_grid_graph_4.txt,40,20,0.6432657241821289
# Simulated_Annealing,complete_grid_graph_5.txt,50,24,0.9671995639801025
# Simulated_Annealing,complete_grid_graph_6.txt,60,29,1.3435251712799072
# Simulated_Annealing,complete_grid_graph_7.txt,70,34,1.7473177909851074
# Simulated_Annealing,complete_grid_graph_8.txt,80,39,2.2954494953155518
# Simulated_Annealing,complete_grid_graph_9.txt,90,43,2.8509860038757324
# Simulated_Annealing,complete_grid_graph_10.txt,100,45,2.9045464992523193
# Simulated_Annealing,incomplete_grid_graph_1.txt,10,3,0.053591012954711914
# Simulated_Annealing,incomplete_grid_graph_2.txt,20,8,0.14548087120056152
# Simulated_Annealing,incomplete_grid_graph_3.txt,30,15,0.37479734420776367
# Simulated_Annealing,incomplete_grid_graph_4.txt,40,18,0.6440503597259521
# Simulated_Annealing,incomplete_grid_graph_5.txt,50,20,0.9595789909362793
# Simulated_Annealing,incomplete_grid_graph_6.txt,60,26,1.4184248447418213
# Simulated_Annealing,incomplete_grid_graph_7.txt,70,29,1.9892876148223877
# Simulated_Annealing,incomplete_grid_graph_8.txt,80,34,2.141310930252075
# Simulated_Annealing,incomplete_grid_graph_9.txt,90,38,2.961108684539795
# Simulated_Annealing,incomplete_grid_graph_10.txt,100,41,3.5241568088531494
# Simulated_Annealing,random_d_regular_graph_1.txt,10,6,0.07210350036621094
# Simulated_Annealing,random_d_regular_graph_2.txt,20,11,0.18891453742980957
# Simulated_Annealing,random_d_regular_graph_3.txt,30,15,0.4073173999786377
# Simulated_Annealing,random_d_regular_graph_4.txt,40,19,0.668259859085083
# Simulated_Annealing,random_d_regular_graph_5.txt,50,24,0.9763889312744141
# Simulated_Annealing,random_d_regular_graph_6.txt,60,29,1.356576919555664
# Simulated_Annealing,random_d_regular_graph_7.txt,70,33,1.8306474685668945
# Simulated_Annealing,random_d_regular_graph_8.txt,80,37,2.3275601863861084
# Simulated_Annealing,random_d_regular_graph_9.txt,90,40,2.9593162536621094
# Simulated_Annealing,random_d_regular_graph_10.txt,100,45,3.598734140396118
# Simulated_Annealing,random_graph_1.txt,10,6,0.07106614112854004
# Simulated_Annealing,random_graph_2.txt,20,12,0.2027580738067627
# Simulated_Annealing,random_graph_3.txt,30,20,0.4255251884460449
# Simulated_Annealing,random_graph_4.txt,40,23,0.6573300361633301
# Simulated_Annealing,random_graph_5.txt,50,28,0.9737155437469482
# Simulated_Annealing,random_graph_6.txt,60,38,1.330871343612671
# Simulated_Annealing,random_graph_7.txt,70,45,1.8184962272644043
# Simulated_Annealing,random_graph_8.txt,80,54,2.1664130687713623
# Simulated_Annealing,random_graph_9.txt,90,60,2.3347487449645996
# Simulated_Annealing,random_graph_10.txt,100,68,2.901784658432007
# Simulated_Annealing,scale_free_graph_1.txt,100,77,2.870764970779419
# Simulated_Annealing,scale_free_graph_2.txt,100,72,2.8432421684265137
# Simulated_Annealing,scale_free_graph_3.txt,100,75,2.9099960327148438
# Simulated_Annealing,scale_free_graph_4.txt,100,77,3.250405788421631
# Simulated_Annealing,scale_free_graph_5.txt,100,71,3.623971939086914
# Simulated_Annealing,scale_free_graph_6.txt,100,70,3.6338953971862793
# Simulated_Annealing,scale_free_graph_7.txt,100,77,3.2508533000946045
# Simulated_Annealing,scale_free_graph_8.txt,100,74,2.8694918155670166
# Simulated_Annealing,scale_free_graph_9.txt,100,70,2.9356722831726074
# Simulated_Annealing,scale_free_graph_10.txt,100,74,2.979423999786377
