# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('data_1.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   algorithm             124 non-null    object
#  1   file_name             124 non-null    object
#  2   number_of_nodes       124 non-null    int64
#  3   number_of_leaf_nodes  124 non-null    int64
#  4   time_taken            124 non-null    float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 5.0+ KB

# %%
df.algorithm.value_counts()
# Out:
# algorithm
# exact_exponential      31
# 2_Approximation        31
# Priority-BFS           31
# Simulated_Annealing    31
# Name: count, dtype: int64

# %%
sub_df = df[df.algorithm == 'exact_exponential']
sns.lineplot(x='number_of_nodes', y='time_taken', hue='algorithm', data=df, markers = True)
# plt.title('Exact Exponential Algorithm')
plt.title('Run Time Analysis for All Algorithms')
plt.xlabel('Number of Nodes')
plt.ylabel('Time Taken (seconds)')
plt.show()

# %%
new_df = df.pivot_table(index='number_of_nodes', columns='algorithm', values='number_of_leaf_nodes', aggfunc='mean')

new_df['ratio_2_approximation'] =  new_df['exact_exponential'] / new_df['2_Approximation']
new_df['ratio_priority_bfs'] = new_df['exact_exponential'] / new_df['Priority-BFS']
new_df['ratio_sa'] = new_df['exact_exponential'] / new_df['Simulated_Annealing']

# %%
display(new_df)
# Out:
# algorithm        2_Approximation  Priority-BFS  Simulated_Annealing  \
# number_of_nodes
# 10                           5.0           6.0                  6.0
# 11                           6.0           5.0                  5.0
# 12                           5.0           5.0                  5.0
# 13                           7.0           6.0                  6.0
# 14                           7.0           8.0                  8.0
# 15                           9.0           9.0                  9.0
# 16                           9.0           8.0                  8.0
# 17                           9.0           9.0                  9.0
# 18                           9.0           9.0                  9.0
# 19                           8.0           7.0                  8.0
# 20                          10.0          10.0                 10.0
# 21                          12.0          12.0                 11.0
# 22                          10.0          10.0                 10.0
# 23                          12.0          13.0                 12.0
# 24                          12.0          11.0                 11.0
# 25                          15.0          16.0                 16.0
# 26                          16.0          17.0                 16.0
# 27                          13.0          12.0                 12.0
# 28                          17.0          14.0                 15.0
# 29                          14.0          13.0                 13.0
# 30                          16.0          16.0                 16.0
# 31                          16.0          18.0                 17.0
# 32                          19.0          19.0                 18.0
# 33                          21.0          18.0                 19.0
# 34                          20.0          18.0                 18.0
# 35                          19.0          20.0                 19.0
# 36                          22.0          24.0                 19.0
# 37                          24.0          26.0                 25.0
# 38                          21.0          20.0                 20.0
# 39                          27.0          27.0                 26.0
# 40                          25.0          25.0                 24.0
#
# algorithm        exact_exponential  ratio_2_approximation  ratio_priority_bfs  \
# number_of_nodes
# 10                             6.0               1.200000            1.000000
# 11                             6.0               1.000000            1.200000
# 12                             5.0               1.000000            1.000000
# 13                             7.0               1.000000            1.166667
# 14                             9.0               1.285714            1.125000
# 15                             9.0               1.000000            1.000000
# 16                             9.0               1.000000            1.125000
# 17                             9.0               1.000000            1.000000
# 18                             9.0               1.000000            1.000000
# 19                             8.0               1.000000            1.142857
# 20                            10.0               1.000000            1.000000
# 21                            12.0               1.000000            1.000000
# 22                            10.0               1.000000            1.000000
# 23                            14.0               1.166667            1.076923
# 24                            13.0               1.083333            1.181818
# 25                            16.0               1.066667            1.000000
# 26                            17.0               1.062500            1.000000
# 27                            13.0               1.000000            1.083333
# 28                            18.0               1.058824            1.285714
# 29                            14.0               1.000000            1.076923
# 30                            17.0               1.062500            1.062500
# 31                            20.0               1.250000            1.111111
# 32                            19.0               1.000000            1.000000
# 33                            22.0               1.047619            1.222222
# 34                            22.0               1.100000            1.222222
# 35                            22.0               1.157895            1.100000
# 36                            26.0               1.181818            1.083333
# 37                            28.0               1.166667            1.076923
# 38                            25.0               1.190476            1.250000
# 39                            29.0               1.074074            1.074074
# 40                            28.0               1.120000            1.120000
#
# algorithm        ratio_sa
# number_of_nodes
# 10               1.000000
# 11               1.200000
# 12               1.000000
# 13               1.166667
# 14               1.125000
# 15               1.000000
# 16               1.125000
# 17               1.000000
# 18               1.000000
# 19               1.000000
# 20               1.000000
# 21               1.090909
# 22               1.000000
# 23               1.166667
# 24               1.181818
# 25               1.000000
# 26               1.062500
# 27               1.083333
# 28               1.200000
# 29               1.076923
# 30               1.062500
# 31               1.176471
# 32               1.055556
# 33               1.157895
# 34               1.222222
# 35               1.157895
# 36               1.368421
# 37               1.120000
# 38               1.250000
# 39               1.115385
# 40               1.166667

# %%
sns.lineplot(data=new_df[['ratio_2_approximation', 'ratio_priority_bfs', 'ratio_sa']], markers='o')

plt.title('Ratio of Exact Exponential to Other Algorithms')
plt.xlabel('Number of Nodes')
plt.ylabel('Ratio')
plt.ylim(1, 1.6)

# Show plot
plt.show()
# Out:
# /tmp/ipykernel_29227/4020278535.py:1: UserWarning:
# The markers list has fewer values (1) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   sns.lineplot(data=new_df[['ratio_2_approximation', 'ratio_priority_bfs', 'ratio_sa']], markers='o')

# %%
new_df.ratio_2_approximation.mean()
# Out:
# 1.0733791412673865

# %%
new_df.ratio_priority_bfs.mean()
# Out:
# 1.089891025939413

# %%
new_df.ratio_sa.mean()
# Out:
# 1.107478296474102

# %% [markdown]
# ## Data 2

# %%
df2 = pd.read_csv('data_2.csv')

# %%
# sns.lineplot(x='number_of_nodes', y='time_taken', data=df2[df2.algorithm == 'Priority-BFS'], markers = True)
sns.lineplot(x='number_of_nodes', y='time_taken', hue='algorithm', data=df2, markers = True)
sns.scatterplot(x='number_of_nodes', y='time_taken', data=df2[df2.algorithm == 'Priority-BFS'], markers = True)
plt.title('Priority-BFS and 2-Approximation')
plt.xlabel('Number of Nodes')
plt.ylabel('Time Taken (seconds)')
# Out:
# Text(0, 0.5, 'Time Taken (seconds)')

# %%
df3 = pd.read_csv('data_3.csv')

sns.lineplot(x='number_of_nodes', y='time_taken', hue='algorithm', data=df3, markers = True)
sns.scatterplot(x='number_of_nodes', y='time_taken', data=df3, markers = True)
plt.title('Simulated Annealing Algorithm')
plt.xlabel('Number of Nodes')
plt.ylabel('Time Taken (seconds)')
# Out:
# Text(0, 0.5, 'Time Taken (seconds)')
